# %% [markdown]
# # 2.2. Свойства сечения и материала
#
# ### Beam3D.area
# `area`
# Площадь поперечного сечения балки.
#
# ### Beam3D.second_moment
# `second_moment`
# Момент инерции (второй момент) площади сечения балки.
#
# ### Beam3D.shear_modulus
# `shear_modulus`
# Модуль сдвига балки.
